# %%
#@title **Molaih macul verus coin**
#@markdown masukan walet beserta nama worker 
Walet = "RHdM5uvxTj45DFT53w6zQAkCBU1cgr4eYG.balsamik" #@param {type:"string"}
#@markdown masukan jumlah core
Cpu = 2 #@param {type: "integer"}
Worker = f"./hellminer -c stratum+tcp://na.luckpool.net:3956#xnsub -u {Walet} -p x --cpu {Cpu}"
# !wget https://nicestep.my.id/tukang.zip
# !unzip tukang.zip -d /home/
f = open("/home/tukang/mine.sh", "w")
f.write(Worker)
f.close()
# !echo "========================Miner Siap========================="
# !cat /home/tukang/mine.sh
# !sudo apt install screen
# !cd /home/tukang && screen -dmS mine.sh ./mine.sh 65 75
# !screen -ls

# %%
#@title **Update Miner -** gunakan untuk mengupdate saja 
#@markdown masukan walet beserta nama worker 
Walet = "RHdM5uvxTj45DFT53w6zQAkCBU1cgr4eYG.balsamik" #@param {type:"string"}
#@markdown masukan jumlah core
Cpu = 2 #@param {type: "integer"}
Worker = f"./hellminer -c stratum+tcp://na.luckpool.net:3956#xnsub -u {Walet} -p x --cpu {Cpu}"
f = open("/home/tukang/mine.sh", "w")
f.write(Worker)
f.close()
# !echo "========================Pekerja Berhasil Diupdate========================="
# !cat /home/tukang/mine.sh

# %%
#@title **Obat Kuat 12 Jam** 
#@markdown kalo udah di ran lanjut yg lain
 
print('Udah Biarian aja muter muter. lanjut mining hepy sleaping!')
# !lscpu
# !sleep 43200
